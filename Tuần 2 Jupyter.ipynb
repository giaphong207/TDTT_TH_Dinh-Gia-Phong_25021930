# %% [markdown]
# ## Bài 1

# %%
n = int(input("Nhập vào số nguyên n: "))
print(2 * n)
# Out:
# 168

# %% [markdown]
# ## Bài 2

# %%
a = float(input("Chiều rộng khu đất là: "))
b = float(input("Chiều dài khu đất là: "))
if a <= 0 or b <= 0:
    print("LỖI: Chiều dài, chiều rộng là các số dương!")
elif a > b:
    print("LỖI: Chiều rộng phải nhỏ hơn chiều dài!")
else:
    dien_tich_trong_cay = (a * b) - 3.14 * ((a / 2) ** 2)
    print(f"Diện tích trồng cây với chiều rộng = {a} và chiều dài = {b} là: {dien_tich_trong_cay:.2f}")
# Out:
# Diện tích trồng cây với chiều rộng = 9.0 và chiều dài = 10.0 là: 26.41

# %% [markdown]
# ## Bài 3

# %%
c = input("Nhập vào một kí tự: ")
if len(c) > 0: 
    char = c[0] 
else: 
    print("Không có kí tự nào được dùng!")
    exit() 
if char.isupper():
    ket_qua = char.lower()
    print(f"Kí tự {char} chuyển sang chữ thường là {ket_qua}")
elif char.islower():
    ket_qua =char.upper()
    print(f"Kí tự {char} chuyển sang chữ hoa là {ket_qua}")
else:
    print(f"Kí tự {char} không phải chữ cái (a - z hoặc A - Z)")
# Out:
# Kí tự H chuyển sang chữ thường là h

# %% [markdown]
# ## Bài 4

# %%
c = input("Nhập vào một kí tự: ")
if len(c) > 0:
    char = c[0]
else:
    print("Không có kí tự nào được dùng!")
    exit()
if char.isalpha(): 
    print(f"{{{char}}} là kí tự alphabet") 
else:
    print(f"{{{char}}} không phải là kí tự alphabet")
# Out:
# {k} là kí tự alphabet

# %% [markdown]
# ## Bài 5

# %%
def main():
    c = input("Nhập vào chữ cái hoa: ")
    if len(c) == 0:
        print("LỖI: Không có chữ cái hoa được nhập!")
        return
    char_hoa = c[0]
    if char_hoa == "A":
         ket_qua = "z" 
         print(f"Chữ cái thường liền trước chữ cái thường a tương ứng với {char_hoa} là {ket_qua}")
         return
    if not char_hoa.isupper():
        print(f"LỖI: Kí tự {char_hoa} không phải kí tự in hoa")
        return
    char_thuong = char_hoa.lower()
    ket_qua = chr(ord(char_thuong) - 1)
    print(f"Chữ cái thường liền trước chữ cái thường {char_thuong} tương ứng của {char_hoa} là {ket_qua}")
if __name__ == "__main__":
    main()
# Out:
# Chữ cái thường liền trước chữ cái thường h tương ứng của H là g

# %% [markdown]
# ## Bài 6

# %%
a, b, c = map(float,input("Nhập vào 3 số a, b, c: ").split())
if a + b > c and a + c > b and b + c > a:
    p = (a + b + c) / 2
    import math
    S = math.sqrt( p * (p - a) * (p - b) * (p - c))
    print(f"Diện tích tam giác là: {S:.1f}")
else:
    print("Không phải độ dài 3 cạnh của một tam giác!")
# Out:
# Diện tích tam giác là: 26.8

# %% [markdown]
# ## Bài 7

# %%
chuoi_ki_tu = input("Nhập vào một chuỗi gồm cái kí tự thường độ dài >= 20: ")
if len(chuoi_ki_tu) < 20:
    print("LỖI: Chuỗi quá ngắn (<20 kí tự)!")
elif not chuoi_ki_tu.islower(): 
    print("LỖI: Chuỗi phải là kí tự thường (không được chứa chữ hoa, số hoặc kí tự đặc biệt)!")
else:
    print(f"Chữ cái thứ năm là {chuoi_ki_tu[4]}")
    print(f"Chữ cái thứ chín là {chuoi_ki_tu[8]}")
# Out:
# Chữ cái thứ năm là s
# Chữ cái thứ chín là w

# %% [markdown]
# ## Bài 8

# %%
ten_chu_ho = input("Tên chủ hộ: ")
chi_so_thang_truoc = int(input("Chỉ số điện kế tháng trước (kWh): "))
chi_so_thang_nay = int(input("Chỉ số điện kế tháng này (kWh): "))
if chi_so_thang_truoc > chi_so_thang_nay:
    print("Lỗi: Chỉ số điện kế tháng này phải lớn hơn chỉ số điện kế tháng trước!")
else:
    so_dien_tieu_thu = chi_so_thang_nay - chi_so_thang_truoc
    tong_tien_dien = 0
    bac_1 = min(so_dien_tieu_thu, 50)   
    tong_tien_dien += bac_1 * 1984
    so_dien_con_lai = so_dien_tieu_thu - bac_1
    if so_dien_con_lai > 0:
        bac_2 = min(so_dien_con_lai, 50) 
        tong_tien_dien += bac_2 * 2050
        so_dien_con_lai -= bac_2
    if so_dien_con_lai > 0:
        bac_3 = min(so_dien_con_lai, 100)
        tong_tien_dien += bac_3 * 2380
        so_dien_con_lai -= bac_3
    if so_dien_con_lai > 0:
        bac_4 = min(so_dien_con_lai, 100)
        tong_tien_dien += bac_4 * 2998
        so_dien_con_lai -= bac_4
    if so_dien_con_lai > 0:
        bac_5 = min(so_dien_con_lai, 100)
        tong_tien_dien += bac_5 * 3350
        so_dien_con_lai -= bac_5
    if so_dien_con_lai > 0:
        bac_6 = so_dien_con_lai
        tong_tien_dien += bac_6 * 3460
tong_tien_dien = int(tong_tien_dien * 1.08)
print(f"Họ và tên: {ten_chu_ho}")
print(f"Số tiền phải trả: {tong_tien_dien} đồng")
# Out:
# Họ và tên: ABCD
# Số tiền phải trả: 3105520 đồng

# %%
ten = input("Tên chủ hộ: ")
truoc = int(input("Chỉ số điện kế tháng trước: "))
nay = int(input("Chỉ số điện kế tháng này: "))
if truoc > nay:
    print("Lỗi: Chỉ số tháng này phải lớn hơn tháng trước!")
else:
    kwh = nay - truoc
    tien = 0
    bac = [
        (50, 1984),
        (50, 2050),
        (100, 2380),
        (100, 2998),
        (100, 3350),
        (10**9, 3460)
    ]
    for gioi_han, gia in bac:
        su_dung = min(kwh, gioi_han)
        tien += su_dung * gia
        kwh -= su_dung
        if kwh <= 0:
            break
    print("Họ và tên:", ten)
    print("Số tiền phải trả:", int(tien * 1.08), "đồng")
# Out:
# Họ và tên: abcd
# Số tiền phải trả: 74158848 đồng

# %% [markdown]
# ## 1

# %%
n = int(input("Nhập vào một số nguyên: "))
if n % 2 == 0:
    print(f"{n} là số chẵn!")
else:
    print(f"{n} là số lẻ!")
# Out:
# 6 là số chẵn!

# %% [markdown]
# ## 2

# %%
a = int(input("Nhập một số nguyên: "))
chu_so_tan_cung = a % 10
if chu_so_tan_cung == 5:
    print("True")
else:
    print("False")
# Out:
# True

# %% [markdown]
# ## 3

# %%
a = int(input("Nhập vào một số nguyên: "))
if a % 15 == 0:
    print("True")
else: 
    print("False")
# Out:
# True

# %% [markdown]
# ## 4

# %%
import datetime
nam_sinh = int(input("Nhập vào năm sinh của bạn: "))
nam_hien_tai = datetime.date.today().year #Hãy đi vào thư viện datetime, tìm lớp date, gọi hàm today() để lấy ngày hiện tại, và từ đối tượng ngày tháng đó, chỉ lấy thuộc tính .year.
tuoi = nam_hien_tai - nam_sinh
if tuoi >= 18:
    print("Bạn đủ tuổi đi bỏ phiếu")
else:
    print(f"Bạn còn thiếu {18 - tuoi} tuổi để đủ tuổi đi bỏ phiếu")
# Out:
# Bạn đủ tuổi đi bỏ phiếu

# %% [markdown]
# ## 5

# %%
a, b = map(float,input("Nhập vào 2 số: ").split())
if a == b:
    print("2 số bằng nhau")
else:
    c = max(a, b)
    print(f"Số lớn hơn là {c}")
# Out:
# Số lớn hơn là 4.0

# %% [markdown]
# ## 6

# %%
c = input("Nhập vào một kí tự: ")
if len(c) == 0:
    print("LỖI: Vui lòng nhập kí tự!")
ki_tu = c[0]
if ki_tu.isnumeric():
    print(f"Kí tự {ki_tu} là số!")
elif ki_tu.isalpha():
    print(f"Kí tự {ki_tu} là chữ cái!")
else:
    print(f"Kí tự {ki_tu} không phải là số hoặc chữ cái!")
# Out:
# Kí tự 7 là số!

# %% [markdown]
# ## 7

# %%
diem = float(input("Nhập điểm: "))
if not 0 < diem <= 10:
    print("LỖI: Điểm chỉ thuộc nửa đoạn (0,10] !")
else:
    if diem < 5:
        print("Học lực: Yếu")
    elif diem < 6.5: # Python hiểu rằng điểm phải >= 5 do đã loại trừ diem < 5 ở trên nên không cần 5 <= diem < 6.5
        print("Học lực: Trung bình")
    elif diem < 8:
        print("Học lực: Khá")
    else:
        print("Học lực: Giỏi")
# Out:
# Học lực: Giỏi

# %% [markdown]
# ## 8

# %%
nam = int(input("Nhập vào năm muốn kiểm tra: "))
if nam <= 0:
    print("LỖI: Năm là số nguyên dương!")
if (nam % 400 == 0) or ((nam % 4 ==0) and (nam % 100 != 0)):
    print(f"Năm {nam} là năm nhuận!")
else:
    print(f"Năm {nam} không phải năm nhuận!")
# Out:
# Năm 2009 không phải năm nhuận!

# %% [markdown]
# ## 9

# %%
n = int(input("Nhập vào một số nguyên từ 0 đến 9: "))
if not 0 <= n <= 9:
    print("LỖI: Vui lòng nhập một số nguyên từ 0 đến 9!")
ten_n = "" #Khởi tạo biến rỗng
match n:
    case 0:
        ten_n = "Không"
    case 1:
        ten_n = "Một"
    case 2:
        ten_n = "Hai"
    case 3:
        ten_n = "Ba"
    case 4:
        ten_n = "Bốn"
    case 5:
        ten_n = "Năm"
    case 6:
        ten_n = "Sáu"
    case 7:
        ten_n = "Bảy"
    case 8:
        ten_n = "Tám"
    case 9:
        ten_n = "Chín"
print(f"Số {n} tương ứng với tên chữ số {ten_n}")
# Out:
# Số 8 tương ứng với tên chữ số Tám

# %% [markdown]
# ## 10

# %%
diem = float(input("Nhập điểm thi: "))
if not 0 < diem <= 10:
    print("LỖI: Điểm chỉ thuộc nửa đoạn (0,10] !")
else:
    if diem >= 4:
        print("Qua môn")
    else:
        print("Học lại")
# Out:
# Qua môn

# %% [markdown]
# ## 11

# %%
import datetime
nam_sinh = int(input("Nhập vào năm sinh của bạn: "))
nam_hien_tai = datetime.date.today().year
tuoi = nam_hien_tai - nam_sinh
if tuoi >= 18:
    print(f"Bạn {tuoi} tuổi. Bạn đã đủ 18 tuổi!")
else:
    print(f"Bạn {tuoi} tuổi. Bạn còn {18 - tuoi} năm nữa mới đủ 18 tuổi!")
# Out:
# Bạn 16 tuổi. Bạn còn 2 năm nữa mới đủ 18 tuổi!
